# %%
import pyro
import pyro.distributions as dist
import torch
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from scipy.stats import ortho_group

# %%
N = 1000
D = 3
K = 1

# %%
W = pyro.sample('W', dist.Normal(0.,1.).expand([K,D]))

# %%
W
# Out:
# tensor([[0.4746, 0.1720, 0.2949]])

# %%
z = pyro.sample('W', dist.Normal(0.,1.).expand([N,K]))

# %%
sigma = pyro.sample('sigma', dist.LogNormal(-1.,1.).expand([D]))
#sigma = pyro.sample('sigma', dist.InverseGamma(1.,1.).expand([D]))

# %%
Sigma = torch.diag(sigma)

# %%
Sigma
# Out:
# tensor([[0.0649, 0.0000, 0.0000],
#         [0.0000, 0.2365, 0.0000],
#         [0.0000, 0.0000, 0.0999]])

# %%
x = pyro.sample('x', dist.MultivariateNormal(torch.matmul(z,W),Sigma))

# %%
X = x.T.numpy()

# %%
Q = ortho_group.rvs(dim=D)

# %%
Wvecs = W.T.numpy()

# %%
Wvecs
# Out:
# array([[0.474615  ],
#        [0.17200005],
#        [0.2948561 ]], dtype=float32)

# %%
WR = np.matmul(W,Q)

# %%
WR
# Out:
# tensor([[-0.1793, -0.3265,  0.4506]], dtype=torch.float64)

# %%
def cone_obj(vectors):
    return  go.Cone(x=vectors[0],
                   y=vectors[1], 
                   z=vectors[2], 
                   u=vectors[0], 
                   v=vectors[1], 
                   w=vectors[2])

# %%
data=go.Scatter3d(
    x=X[0], y=X[1], z=X[2], mode='markers',
    marker=dict(size=2),opacity=.6)
Wvectors =
Rvectors = go.Cone(x=Q[0],
                   y=Q[1], 
                   z=Q[2], 
                   u=Q[0], 
                   v=Q[1], 
                   w=Q[2])
fig = go.Figure()
fig.add_trace(data)
fig.add_trace(Wvectors)
#fig.add_trace(Rvectors)
fig.show()
# Out:
# <div>
#
#
#             <div id="5fbbd0ff-1748-46a7-973a-8eb2574993e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5fbbd0ff-1748-46a7-973a-8eb2574993e5")) {
#                     Plotly.newPlot(
#                         '5fbbd0ff-1748-46a7-973a-8eb2574993e5',
#                         [{"marker": {"size": 2}, "mode": "markers", "opacity": 0.6, "type": "scatter3d", "x": [-0.8380172252655029, 0.5797858238220215, 0.24838295578956604, 0.20165546238422394, -0.09705261141061783, -0.22943273186683655, 0.5529726147651672, 0.25607535243034363, 0.37606459856033325, 0.6714096069335938, 0.339377760887146, 0.34167423844337463, 0.261699378490448, 0.39805805683135986, -0.18265464901924133, -0.3463064432144165, -0.4376842975616455, -0.7116174697875977, 0.2895548939704895, 0.14097636938095093, 0.10901913791894913, -0.7435680627822876, 0.5438380241394043, -0.823409378528595, -0.4738394021987915, -0.5319113731384277, 0.5179738402366638, -0.4022301137447357, -0.5506108999252319, -0.37846413254737854, -0.144185408949852, 1.2249736785888672, -0.38925671577453613, -0.20772713422775269, -0.23827439546585083, -0.6016464233398438, -0.1776229739189148, -0.9587247967720032, 0.06797585636377335, 0.5054836273193359, 0.0883636325597763, -0.43993204832077026, -0.304019033908844, -0.012373805046081543, 0.5824916362762451, 0.12078